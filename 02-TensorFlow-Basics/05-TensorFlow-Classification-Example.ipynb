# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmp3ktymcx6
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmp3ktymcx6', '_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_tf_random_seed': 1, '_save_summary_steps': 100, '_session_config': None, '_keep_checkpoint_max': 5}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmp3ktymcx6/model.ckpt.
# INFO:tensorflow:loss = 6.93147, step = 1
# INFO:tensorflow:global_step/sec: 456.907
# INFO:tensorflow:loss = 6.17698, step = 101 (0.220 sec)
# INFO:tensorflow:global_step/sec: 539.22
# INFO:tensorflow:loss = 4.71587, step = 201 (0.185 sec)
# INFO:tensorflow:global_step/sec: 487.313
# INFO:tensorflow:loss = 4.09984, step = 301 (0.205 sec)
# INFO:tensorflow:global_step/sec: 521.385
# INFO:tensorflow:loss = 4.60503, step = 401 (0.192 sec)
# INFO:tensorflow:global_step/sec: 501.6
# INFO:tensorflow:loss = 7.1691, step = 501 (0.201 sec)
# INFO:tensorflow:global_step/sec: 492.436
# INFO:tensorflow:loss = 4.35762, step = 601 (0.203 sec)
# INFO:tensorflow:global_step/sec: 461.483
# INFO:tensorflow:loss = 4.28324, step = 701 (0.216 sec)
# INFO:tensorflow:global_step/sec: 470.903
# INFO:tensorflow:loss = 4.74762, step = 801 (0.213 sec)
# INFO:tensorflow:global_step/sec: 544.807
# INFO:tensorflow:loss = 4.76732, step = 901 (0.184 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmp3ktymcx6/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.39687.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2020-02-14-22:41:18
# INFO:tensorflow:Restoring parameters from /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmp3ktymcx6/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2020-02-14-22:41:19
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.720472, accuracy_baseline = 0.65748, auc = 0.785395, auc_precision_recall = 0.617598, average_loss = 0.532292, global_step = 1000, label/mean = 0.34252, loss = 5.20008, prediction/mean = 0.34951

# %%
results
# Out:
# {'accuracy': 0.72047246,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78539479,
#  'auc_precision_recall': 0.61759758,
#  'average_loss': 0.53229195,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2000828,
#  'prediction/mean': 0.3495096}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmp3ktymcx6/model.ckpt-1000
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52859706], dtype=float32),
#   'logits': array([ 0.11451316], dtype=float32),
#   'probabilities': array([ 0.47140297,  0.52859706], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58554417], dtype=float32),
#   'logits': array([ 0.34557533], dtype=float32),
#   'probabilities': array([ 0.4144558 ,  0.58554417], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35929415], dtype=float32),
#   'logits': array([-0.57842904], dtype=float32),
#   'probabilities': array([ 0.64070588,  0.35929415], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31698197], dtype=float32),
#   'logits': array([-0.76767635], dtype=float32),
#   'probabilities': array([ 0.68301803,  0.31698197], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13806689], dtype=float32),
#   'logits': array([-1.8314395], dtype=float32),
#   'probabilities': array([ 0.86193311,  0.13806687], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67505246], dtype=float32),
#   'logits': array([ 0.73112667], dtype=float32),
#   'probabilities': array([ 0.32494754,  0.67505246], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55175126], dtype=float32),
#   'logits': array([ 0.20774901], dtype=float32),
#   'probabilities': array([ 0.44824877,  0.55175126], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33313519], dtype=float32),
#   'logits': array([-0.69403893], dtype=float32),
#   'probabilities': array([ 0.66686475,  0.33313519], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22841987], dtype=float32),
#   'logits': array([-1.21725512], dtype=float32),
#   'probabilities': array([ 0.7715801 ,  0.22841986], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24013376], dtype=float32),
#   'logits': array([-1.15194643], dtype=float32),
#   'probabilities': array([ 0.75986624,  0.24013373], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11901486], dtype=float32),
#   'logits': array([-2.00179243], dtype=float32),
#   'probabilities': array([ 0.88098508,  0.11901484], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14682312], dtype=float32),
#   'logits': array([-1.75973821], dtype=float32),
#   'probabilities': array([ 0.85317683,  0.14682312], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26116475], dtype=float32),
#   'logits': array([-1.03992343], dtype=float32),
#   'probabilities': array([ 0.73883522,  0.26116475], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55187708], dtype=float32),
#   'logits': array([ 0.20825791], dtype=float32),
#   'probabilities': array([ 0.44812286,  0.55187708], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16099901], dtype=float32),
#   'logits': array([-1.65081358], dtype=float32),
#   'probabilities': array([ 0.839001  ,  0.16099903], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30979097], dtype=float32),
#   'logits': array([-0.80109668], dtype=float32),
#   'probabilities': array([ 0.69020903,  0.309791  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34974766], dtype=float32),
#   'logits': array([-0.62014866], dtype=float32),
#   'probabilities': array([ 0.65025234,  0.34974763], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11863974], dtype=float32),
#   'logits': array([-2.00537491], dtype=float32),
#   'probabilities': array([ 0.88136023,  0.11863974], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32487774], dtype=float32),
#   'logits': array([-0.73144495], dtype=float32),
#   'probabilities': array([ 0.67512232,  0.32487774], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13464905], dtype=float32),
#   'logits': array([-1.86046338], dtype=float32),
#   'probabilities': array([ 0.8653509 ,  0.13464905], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20245413], dtype=float32),
#   'logits': array([-1.37102592], dtype=float32),
#   'probabilities': array([ 0.79754585,  0.20245415], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28562421], dtype=float32),
#   'logits': array([-0.91673213], dtype=float32),
#   'probabilities': array([ 0.71437579,  0.28562421], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64788735], dtype=float32),
#   'logits': array([ 0.60976553], dtype=float32),
#   'probabilities': array([ 0.35211271,  0.64788735], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20830961], dtype=float32),
#   'logits': array([-1.335145], dtype=float32),
#   'probabilities': array([ 0.79169041,  0.20830961], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16522203], dtype=float32),
#   'logits': array([-1.61987555], dtype=float32),
#   'probabilities': array([ 0.83477801,  0.16522205], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73341215], dtype=float32),
#   'logits': array([ 1.01200366], dtype=float32),
#   'probabilities': array([ 0.26658791,  0.73341215], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17328681], dtype=float32),
#   'logits': array([-1.56250978], dtype=float32),
#   'probabilities': array([ 0.82671326,  0.17328681], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29140225], dtype=float32),
#   'logits': array([-0.88858342], dtype=float32),
#   'probabilities': array([ 0.70859772,  0.29140222], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.09523205], dtype=float32),
#   'logits': array([-2.25136185], dtype=float32),
#   'probabilities': array([ 0.90476787,  0.09523205], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5642848], dtype=float32),
#   'logits': array([ 0.25857019], dtype=float32),
#   'probabilities': array([ 0.43571523,  0.5642848 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.93489915], dtype=float32),
#   'logits': array([ 2.66450047], dtype=float32),
#   'probabilities': array([ 0.06510089,  0.93489915], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38152081], dtype=float32),
#   'logits': array([-0.48309821], dtype=float32),
#   'probabilities': array([ 0.61847919,  0.38152078], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30766192], dtype=float32),
#   'logits': array([-0.81107295], dtype=float32),
#   'probabilities': array([ 0.69233811,  0.30766189], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53031152], dtype=float32),
#   'logits': array([ 0.12139499], dtype=float32),
#   'probabilities': array([ 0.46968848,  0.53031152], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22830217], dtype=float32),
#   'logits': array([-1.21792305], dtype=float32),
#   'probabilities': array([ 0.77169788,  0.22830218], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35449952], dtype=float32),
#   'logits': array([-0.59931898], dtype=float32),
#   'probabilities': array([ 0.64550048,  0.35449952], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50239587], dtype=float32),
#   'logits': array([ 0.00958347], dtype=float32),
#   'probabilities': array([ 0.49760416,  0.50239587], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60670716], dtype=float32),
#   'logits': array([ 0.43349171], dtype=float32),
#   'probabilities': array([ 0.39329284,  0.60670716], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73397285], dtype=float32),
#   'logits': array([ 1.0148735], dtype=float32),
#   'probabilities': array([ 0.26602718,  0.73397285], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30366117], dtype=float32),
#   'logits': array([-0.82992387], dtype=float32),
#   'probabilities': array([ 0.69633883,  0.30366117], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17032798], dtype=float32),
#   'logits': array([-1.58330464], dtype=float32),
#   'probabilities': array([ 0.82967204,  0.17032798], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48740521], dtype=float32),
#   'logits': array([-0.05038977], dtype=float32),
#   'probabilities': array([ 0.51259476,  0.48740518], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1370824], dtype=float32),
#   'logits': array([-1.83973706], dtype=float32),
#   'probabilities': array([ 0.86291754,  0.13708238], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49733451], dtype=float32),
#   'logits': array([-0.01066196], dtype=float32),
#   'probabilities': array([ 0.50266546,  0.49733451], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12754148], dtype=float32),
#   'logits': array([-1.9228735], dtype=float32),
#   'probabilities': array([ 0.87245846,  0.12754147], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10510358], dtype=float32),
#   'logits': array([-2.14176154], dtype=float32),
#   'probabilities': array([ 0.89489645,  0.10510359], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5851199], dtype=float32),
#   'logits': array([ 0.34382713], dtype=float32),
#   'probabilities': array([ 0.41488013,  0.5851199 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18028456], dtype=float32),
#   'logits': array([-1.51442075], dtype=float32),
#   'probabilities': array([ 0.81971544,  0.18028457], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1916704], dtype=float32),
#   'logits': array([-1.43919265], dtype=float32),
#   'probabilities': array([ 0.80832964,  0.19167042], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11151314], dtype=float32),
#   'logits': array([-2.07537746], dtype=float32),
#   'probabilities': array([ 0.88848686,  0.11151313], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16402134], dtype=float32),
#   'logits': array([-1.62860656], dtype=float32),
#   'probabilities': array([ 0.83597869,  0.16402134], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23251475], dtype=float32),
#   'logits': array([-1.19416559], dtype=float32),
#   'probabilities': array([ 0.76748526,  0.23251475], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2465269], dtype=float32),
#   'logits': array([-1.11722219], dtype=float32),
#   'probabilities': array([ 0.7534731,  0.2465269], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3390694], dtype=float32),
#   'logits': array([-0.66744411], dtype=float32),
#   'probabilities': array([ 0.66093063,  0.3390694 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12087471], dtype=float32),
#   'logits': array([-1.98417282], dtype=float32),
#   'probabilities': array([ 0.87912524,  0.1208747 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2143877], dtype=float32),
#   'logits': array([-1.29867733], dtype=float32),
#   'probabilities': array([ 0.78561229,  0.2143877 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1982421], dtype=float32),
#   'logits': array([-1.39731765], dtype=float32),
#   'probabilities': array([ 0.80175787,  0.1982421 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20233671], dtype=float32),
#   'logits': array([-1.37175345], dtype=float32),
#   'probabilities': array([ 0.79766333,  0.2023367 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4629449], dtype=float32),
#   'logits': array([-0.14849269], dtype=float32),
#   'probabilities': array([ 0.53705513,  0.46294492], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1565761], dtype=float32),
#   'logits': array([-1.68392754], dtype=float32),
#   'probabilities': array([ 0.8434239,  0.1565761], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21744326], dtype=float32),
#   'logits': array([-1.28062844], dtype=float32),
#   'probabilities': array([ 0.78255677,  0.21744327], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62283796], dtype=float32),
#   'logits': array([ 0.50161123], dtype=float32),
#   'probabilities': array([ 0.37716213,  0.62283796], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6112119], dtype=float32),
#   'logits': array([ 0.45240903], dtype=float32),
#   'probabilities': array([ 0.38878816,  0.6112119 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49302283], dtype=float32),
#   'logits': array([-0.02791035], dtype=float32),
#   'probabilities': array([ 0.50697714,  0.49302286], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34468055], dtype=float32),
#   'logits': array([-0.64250469], dtype=float32),
#   'probabilities': array([ 0.65531945,  0.34468058], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43876109], dtype=float32),
#   'logits': array([-0.2461918], dtype=float32),
#   'probabilities': array([ 0.56123894,  0.43876103], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16403608], dtype=float32),
#   'logits': array([-1.62849903], dtype=float32),
#   'probabilities': array([ 0.8359639 ,  0.16403608], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18175596], dtype=float32),
#   'logits': array([-1.50449574], dtype=float32),
#   'probabilities': array([ 0.8182441 ,  0.18175596], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1473828], dtype=float32),
#   'logits': array([-1.7552774], dtype=float32),
#   'probabilities': array([ 0.8526172,  0.1473828], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11563295], dtype=float32),
#   'logits': array([-2.03445125], dtype=float32),
#   'probabilities': array([ 0.88436705,  0.11563294], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55501705], dtype=float32),
#   'logits': array([ 0.220963], dtype=float32),
#   'probabilities': array([ 0.44498292,  0.55501705], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21758327], dtype=float32),
#   'logits': array([-1.27980578], dtype=float32),
#   'probabilities': array([ 0.7824167 ,  0.21758328], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4059993], dtype=float32),
#   'logits': array([-0.38052917], dtype=float32),
#   'probabilities': array([ 0.59400076,  0.4059993 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5689013], dtype=float32),
#   'logits': array([ 0.27736986], dtype=float32),
#   'probabilities': array([ 0.4310987,  0.5689013], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28874785], dtype=float32),
#   'logits': array([-0.90147316], dtype=float32),
#   'probabilities': array([ 0.71125215,  0.28874788], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61742091], dtype=float32),
#   'logits': array([ 0.47861576], dtype=float32),
#   'probabilities': array([ 0.38257903,  0.61742091], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12103137], dtype=float32),
#   'logits': array([-1.98269939], dtype=float32),
#   'probabilities': array([ 0.87896866,  0.12103138], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57661623], dtype=float32),
#   'logits': array([ 0.30889797], dtype=float32),
#   'probabilities': array([ 0.42338374,  0.57661623], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11426713], dtype=float32),
#   'logits': array([-2.04787636], dtype=float32),
#   'probabilities': array([ 0.88573289,  0.11426714], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51238495], dtype=float32),
#   'logits': array([ 0.04954994], dtype=float32),
#   'probabilities': array([ 0.48761505,  0.51238495], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3097381], dtype=float32),
#   'logits': array([-0.80134392], dtype=float32),
#   'probabilities': array([ 0.6902619 ,  0.30973813], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15216583], dtype=float32),
#   'logits': array([-1.71771407], dtype=float32),
#   'probabilities': array([ 0.84783417,  0.15216585], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52855915], dtype=float32),
#   'logits': array([ 0.11436105], dtype=float32),
#   'probabilities': array([ 0.47144088,  0.52855915], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55918735], dtype=float32),
#   'logits': array([ 0.23786473], dtype=float32),
#   'probabilities': array([ 0.44081262,  0.55918735], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50819951], dtype=float32),
#   'logits': array([ 0.03280091], dtype=float32),
#   'probabilities': array([ 0.49180052,  0.50819951], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15878637], dtype=float32),
#   'logits': array([-1.66728592], dtype=float32),
#   'probabilities': array([ 0.8412137 ,  0.15878639], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30743113], dtype=float32),
#   'logits': array([-0.8121565], dtype=float32),
#   'probabilities': array([ 0.69256884,  0.30743113], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13667376], dtype=float32),
#   'logits': array([-1.84319592], dtype=float32),
#   'probabilities': array([ 0.86332625,  0.13667375], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.68768758], dtype=float32),
#   'logits': array([ 0.78933036], dtype=float32),
#   'probabilities': array([ 0.31231248,  0.68768758], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7954368], dtype=float32),
#   'logits': array([ 1.35801458], dtype=float32),
#   'probabilities': array([ 0.20456316,  0.7954368 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60470581], dtype=float32),
#   'logits': array([ 0.42511189], dtype=float32),
#   'probabilities': array([ 0.39529416,  0.60470581], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20609134], dtype=float32),
#   'logits': array([-1.34864891], dtype=float32),
#   'probabilities': array([ 0.79390866,  0.20609134], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39939997], dtype=float32),
#   'logits': array([-0.4079659], dtype=float32),
#   'probabilities': array([ 0.6006    ,  0.39939994], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35037631], dtype=float32),
#   'logits': array([-0.61738551], dtype=float32),
#   'probabilities': array([ 0.64962369,  0.35037631], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43618819], dtype=float32),
#   'logits': array([-0.25664681], dtype=float32),
#   'probabilities': array([ 0.56381184,  0.43618819], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31043011], dtype=float32),
#   'logits': array([-0.79810929], dtype=float32),
#   'probabilities': array([ 0.68956989,  0.31043011], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43442759], dtype=float32),
#   'logits': array([-0.26380908], dtype=float32),
#   'probabilities': array([ 0.56557244,  0.43442759], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14458419], dtype=float32),
#   'logits': array([-1.7777257], dtype=float32),
#   'probabilities': array([ 0.85541582,  0.14458419], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5353719], dtype=float32),
#   'logits': array([ 0.14172435], dtype=float32),
#   'probabilities': array([ 0.4646281,  0.5353719], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5279941], dtype=float32),
#   'logits': array([ 0.11209381], dtype=float32),
#   'probabilities': array([ 0.47200581,  0.5279941 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23615515], dtype=float32),
#   'logits': array([-1.17387569], dtype=float32),
#   'probabilities': array([ 0.76384485,  0.23615514], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16447276], dtype=float32),
#   'logits': array([-1.62531805], dtype=float32),
#   'probabilities': array([ 0.83552724,  0.16447274], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16219777], dtype=float32),
#   'logits': array([-1.64196563], dtype=float32),
#   'probabilities': array([ 0.83780223,  0.16219777], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26804802], dtype=float32),
#   'logits': array([-1.00454879], dtype=float32),
#   'probabilities': array([ 0.73195195,  0.26804802], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35834828], dtype=float32),
#   'logits': array([-0.58254033], dtype=float32),
#   'probabilities': array([ 0.64165169,  0.35834825], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12551153], dtype=float32),
#   'logits': array([-1.9412415], dtype=float32),
#   'probabilities': array([ 0.87448853,  0.12551154], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29189321], dtype=float32),
#   'logits': array([-0.88620687], dtype=float32),
#   'probabilities': array([ 0.70810676,  0.29189318], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20800841], dtype=float32),
#   'logits': array([-1.33697224], dtype=float32),
#   'probabilities': array([ 0.79199159,  0.20800841], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.08764841], dtype=float32),
#   'logits': array([-2.3426919], dtype=float32),
#   'probabilities': array([ 0.91235161,  0.08764841], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11417342], dtype=float32),
#   'logits': array([-2.04880261], dtype=float32),
#   'probabilities': array([ 0.88582665,  0.11417343], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72147739], dtype=float32),
#   'logits': array([ 0.95180178], dtype=float32),
#   'probabilities': array([ 0.27852261,  0.72147739], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16967382], dtype=float32),
#   'logits': array([-1.58794081], dtype=float32),
#   'probabilities': array([ 0.8303262 ,  0.16967382], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1209752], dtype=float32),
#   'logits': array([-1.98322749], dtype=float32),
#   'probabilities': array([ 0.87902474,  0.1209752 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12988886], dtype=float32),
#   'logits': array([-1.90194178], dtype=float32),
#   'probabilities': array([ 0.87011111,  0.12988886], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43590271], dtype=float32),
#   'logits': array([-0.25780755], dtype=float32),
#   'probabilities': array([ 0.56409729,  0.43590274], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4200995], dtype=float32),
#   'logits': array([-0.32236493], dtype=float32),
#   'probabilities': array([ 0.5799005 ,  0.42009953], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22719125], dtype=float32),
#   'logits': array([-1.22423935], dtype=float32),
#   'probabilities': array([ 0.77280873,  0.22719125], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40690044], dtype=float32),
#   'logits': array([-0.3767938], dtype=float32),
#   'probabilities': array([ 0.59309953,  0.40690038], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16797282], dtype=float32),
#   'logits': array([-1.60006297], dtype=float32),
#   'probabilities': array([ 0.8320272 ,  0.16797282], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21585613], dtype=float32),
#   'logits': array([-1.28998029], dtype=float32),
#   'probabilities': array([ 0.78414387,  0.21585615], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49763751], dtype=float32),
#   'logits': array([-0.00945008], dtype=float32),
#   'probabilities': array([ 0.50236249,  0.49763748], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43538594], dtype=float32),
#   'logits': array([-0.25990957], dtype=float32),
#   'probabilities': array([ 0.56461406,  0.43538594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12888069], dtype=float32),
#   'logits': array([-1.91089177], dtype=float32),
#   'probabilities': array([ 0.87111932,  0.12888069], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35550451], dtype=float32),
#   'logits': array([-0.59492987], dtype=float32),
#   'probabilities': array([ 0.64449555,  0.35550454], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64948809], dtype=float32),
#   'logits': array([ 0.61678982], dtype=float32),
#   'probabilities': array([ 0.35051191,  0.64948809], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49748778], dtype=float32),
#   'logits': array([-0.01004899], dtype=float32),
#   'probabilities': array([ 0.50251222,  0.49748775], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35689896], dtype=float32),
#   'logits': array([-0.58884919], dtype=float32),
#   'probabilities': array([ 0.6431011 ,  0.35689896], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54434973], dtype=float32),
#   'logits': array([ 0.17786646], dtype=float32),
#   'probabilities': array([ 0.45565021,  0.54434973], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20866492], dtype=float32),
#   'logits': array([-1.33299172], dtype=float32),
#   'probabilities': array([ 0.79133511,  0.20866494], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17632493], dtype=float32),
#   'logits': array([-1.54144764], dtype=float32),
#   'probabilities': array([ 0.82367504,  0.17632492], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12279106], dtype=float32),
#   'logits': array([-1.96626091], dtype=float32),
#   'probabilities': array([ 0.87720895,  0.12279107], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24802056], dtype=float32),
#   'logits': array([-1.10919738], dtype=float32),
#   'probabilities': array([ 0.75197941,  0.24802054], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43787369], dtype=float32),
#   'logits': array([-0.24979609], dtype=float32),
#   'probabilities': array([ 0.56212628,  0.43787369], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6591562], dtype=float32),
#   'logits': array([ 0.65953636], dtype=float32),
#   'probabilities': array([ 0.34084377,  0.6591562 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20972325], dtype=float32),
#   'logits': array([-1.32659435], dtype=float32),
#   'probabilities': array([ 0.79027671,  0.20972325], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14948039], dtype=float32),
#   'logits': array([-1.73868227], dtype=float32),
#   'probabilities': array([ 0.85051966,  0.14948039], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37627348], dtype=float32),
#   'logits': array([-0.50539577], dtype=float32),
#   'probabilities': array([ 0.62372655,  0.37627351], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22102533], dtype=float32),
#   'logits': array([-1.25970113], dtype=float32),
#   'probabilities': array([ 0.77897465,  0.22102535], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13851865], dtype=float32),
#   'logits': array([-1.8276484], dtype=float32),
#   'probabilities': array([ 0.86148131,  0.13851866], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17737396], dtype=float32),
#   'logits': array([-1.53424144], dtype=float32),
#   'probabilities': array([ 0.82262605,  0.17737396], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11534481], dtype=float32),
#   'logits': array([-2.03727198], dtype=float32),
#   'probabilities': array([ 0.88465518,  0.1153448 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38905481], dtype=float32),
#   'logits': array([-0.45128715], dtype=float32),
#   'probabilities': array([ 0.61094522,  0.38905481], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75682783], dtype=float32),
#   'logits': array([ 1.1353662], dtype=float32),
#   'probabilities': array([ 0.24317214,  0.75682783], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74878329], dtype=float32),
#   'logits': array([ 1.09213376], dtype=float32),
#   'probabilities': array([ 0.25121668,  0.74878329], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52713227], dtype=float32),
#   'logits': array([ 0.10863578], dtype=float32),
#   'probabilities': array([ 0.47286773,  0.52713227], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45166412], dtype=float32),
#   'logits': array([-0.19394928], dtype=float32),
#   'probabilities': array([ 0.54833591,  0.45166412], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51689529], dtype=float32),
#   'logits': array([ 0.06760693], dtype=float32),
#   'probabilities': array([ 0.48310471,  0.51689529], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10881636], dtype=float32),
#   'logits': array([-2.10288882], dtype=float32),
#   'probabilities': array([ 0.89118361,  0.10881636], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49084845], dtype=float32),
#   'logits': array([-0.03661025], dtype=float32),
#   'probabilities': array([ 0.50915158,  0.49084848], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74520254], dtype=float32),
#   'logits': array([ 1.07318711], dtype=float32),
#   'probabilities': array([ 0.25479746,  0.74520254], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38054311], dtype=float32),
#   'logits': array([-0.48724359], dtype=float32),
#   'probabilities': array([ 0.61945689,  0.38054311], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24627456], dtype=float32),
#   'logits': array([-1.11858106], dtype=float32),
#   'probabilities': array([ 0.75372541,  0.24627458], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32637414], dtype=float32),
#   'logits': array([-0.72463048], dtype=float32),
#   'probabilities': array([ 0.67362589,  0.32637414], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56757355], dtype=float32),
#   'logits': array([ 0.27195799], dtype=float32),
#   'probabilities': array([ 0.43242648,  0.56757355], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22594243], dtype=float32),
#   'logits': array([-1.23136604], dtype=float32),
#   'probabilities': array([ 0.77405757,  0.22594243], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60989392], dtype=float32),
#   'logits': array([ 0.44686639], dtype=float32),
#   'probabilities': array([ 0.39010605,  0.60989392], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36604384], dtype=float32),
#   'logits': array([-0.54922676], dtype=float32),
#   'probabilities': array([ 0.63395613,  0.36604381], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37080044], dtype=float32),
#   'logits': array([-0.52878451], dtype=float32),
#   'probabilities': array([ 0.62919956,  0.37080041], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15390515], dtype=float32),
#   'logits': array([-1.70429492], dtype=float32),
#   'probabilities': array([ 0.84609485,  0.15390515], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17462453], dtype=float32),
#   'logits': array([-1.55320024], dtype=float32),
#   'probabilities': array([ 0.8253755 ,  0.17462455], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16968632], dtype=float32),
#   'logits': array([-1.587852], dtype=float32),
#   'probabilities': array([ 0.83031374,  0.16968633], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39560318], dtype=float32),
#   'logits': array([-0.4238193], dtype=float32),
#   'probabilities': array([ 0.60439682,  0.39560318], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14223315], dtype=float32),
#   'logits': array([-1.79686475], dtype=float32),
#   'probabilities': array([ 0.85776687,  0.14223315], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72023803], dtype=float32),
#   'logits': array([ 0.94564247], dtype=float32),
#   'probabilities': array([ 0.279762  ,  0.72023803], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19517459], dtype=float32),
#   'logits': array([-1.41673088], dtype=float32),
#   'probabilities': array([ 0.80482537,  0.19517457], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49691918], dtype=float32),
#   'logits': array([-0.01232326], dtype=float32),
#   'probabilities': array([ 0.50308079,  0.49691924], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14630069], dtype=float32),
#   'logits': array([-1.76391494], dtype=float32),
#   'probabilities': array([ 0.85369927,  0.14630069], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64779425], dtype=float32),
#   'logits': array([ 0.60935783], dtype=float32),
#   'probabilities': array([ 0.35220569,  0.64779425], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30449149], dtype=float32),
#   'logits': array([-0.82600015], dtype=float32),
#   'probabilities': array([ 0.69550848,  0.30449146], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18642931], dtype=float32),
#   'logits': array([-1.47338068], dtype=float32),
#   'probabilities': array([ 0.81357074,  0.18642932], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30395696], dtype=float32),
#   'logits': array([-0.82852542], dtype=float32),
#   'probabilities': array([ 0.69604307,  0.30395696], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31246379], dtype=float32),
#   'logits': array([-0.78862584], dtype=float32),
#   'probabilities': array([ 0.68753624,  0.31246382], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15813084], dtype=float32),
#   'logits': array([-1.67220187], dtype=float32),
#   'probabilities': array([ 0.84186912,  0.15813082], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69028646], dtype=float32),
#   'logits': array([ 0.80145884], dtype=float32),
#   'probabilities': array([ 0.30971354,  0.69028646], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17967024], dtype=float32),
#   'logits': array([-1.5185833], dtype=float32),
#   'probabilities': array([ 0.82032979,  0.17967024], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16532175], dtype=float32),
#   'logits': array([-1.61915278], dtype=float32),
#   'probabilities': array([ 0.83467823,  0.16532174], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23132217], dtype=float32),
#   'logits': array([-1.2008605], dtype=float32),
#   'probabilities': array([ 0.76867783,  0.23132218], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39418387], dtype=float32),
#   'logits': array([-0.42975903], dtype=float32),
#   'probabilities': array([ 0.60581613,  0.39418387], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25440902], dtype=float32),
#   'logits': array([-1.07523382], dtype=float32),
#   'probabilities': array([ 0.74559093,  0.25440902], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10855788], dtype=float32),
#   'logits': array([-2.10555696], dtype=float32),
#   'probabilities': array([ 0.89144218,  0.10855789], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.82159877], dtype=float32),
#   'logits': array([ 1.52721715], dtype=float32),
#   'probabilities': array([ 0.17840122,  0.82159877], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65683734], dtype=float32),
#   'logits': array([ 0.64923215], dtype=float32),
#   'probabilities': array([ 0.34316257,  0.65683734], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49065611], dtype=float32),
#   'logits': array([-0.03737986], dtype=float32),
#   'probabilities': array([ 0.50934386,  0.49065611], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69071865], dtype=float32),
#   'logits': array([ 0.8034811], dtype=float32),
#   'probabilities': array([ 0.30928138,  0.69071865], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10646367], dtype=float32),
#   'logits': array([-2.12738323], dtype=float32),
#   'probabilities': array([ 0.89353627,  0.10646366], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13656998], dtype=float32),
#   'logits': array([-1.84407568], dtype=float32),
#   'probabilities': array([ 0.86343002,  0.13656999], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19383387], dtype=float32),
#   'logits': array([-1.42528844], dtype=float32),
#   'probabilities': array([ 0.80616617,  0.19383387], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32716954], dtype=float32),
#   'logits': array([-0.72101486], dtype=float32),
#   'probabilities': array([ 0.67283046,  0.32716957], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35720155], dtype=float32),
#   'logits': array([-0.58753103], dtype=float32),
#   'probabilities': array([ 0.64279842,  0.35720155], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54127657], dtype=float32),
#   'logits': array([ 0.16548288], dtype=float32),
#   'probabilities': array([ 0.45872343,  0.54127657], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50775313], dtype=float32),
#   'logits': array([ 0.03101516], dtype=float32),
#   'probabilities': array([ 0.49224681,  0.50775313], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33677575], dtype=float32),
#   'logits': array([-0.67769587], dtype=float32),
#   'probabilities': array([ 0.66322422,  0.33677575], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32272878], dtype=float32),
#   'logits': array([-0.74125952], dtype=float32),
#   'probabilities': array([ 0.67727119,  0.32272875], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33499309], dtype=float32),
#   'logits': array([-0.68568742], dtype=float32),
#   'probabilities': array([ 0.66500688,  0.33499309], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18228874], dtype=float32),
#   'logits': array([-1.50091743], dtype=float32),
#   'probabilities': array([ 0.81771129,  0.18228874], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60440439], dtype=float32),
#   'logits': array([ 0.42385113], dtype=float32),
#   'probabilities': array([ 0.39559558,  0.60440439], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11864313], dtype=float32),
#   'logits': array([-2.00534248], dtype=float32),
#   'probabilities': array([ 0.88135684,  0.11864313], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22122115], dtype=float32),
#   'logits': array([-1.25856423], dtype=float32),
#   'probabilities': array([ 0.77877885,  0.22122115], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51314372], dtype=float32),
#   'logits': array([ 0.05258715], dtype=float32),
#   'probabilities': array([ 0.48685622,  0.51314372], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33794618], dtype=float32),
#   'logits': array([-0.67246026], dtype=float32),
#   'probabilities': array([ 0.66205382,  0.33794618], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1859429], dtype=float32),
#   'logits': array([-1.47659087], dtype=float32),
#   'probabilities': array([ 0.81405711,  0.1859429 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25736308], dtype=float32),
#   'logits': array([-1.05971944], dtype=float32),
#   'probabilities': array([ 0.74263692,  0.25736308], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24765624], dtype=float32),
#   'logits': array([-1.11115181], dtype=float32),
#   'probabilities': array([ 0.75234383,  0.24765623], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12594797], dtype=float32),
#   'logits': array([-1.93727112], dtype=float32),
#   'probabilities': array([ 0.87405205,  0.12594797], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17690994], dtype=float32),
#   'logits': array([-1.5374248], dtype=float32),
#   'probabilities': array([ 0.82309008,  0.17690995], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54080373], dtype=float32),
#   'logits': array([ 0.16357875], dtype=float32),
#   'probabilities': array([ 0.45919624,  0.54080373], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69078922], dtype=float32),
#   'logits': array([ 0.80381155], dtype=float32),
#   'probabilities': array([ 0.30921078,  0.69078922], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57358575], dtype=float32),
#   'logits': array([ 0.29649603], dtype=float32),
#   'probabilities': array([ 0.42641431,  0.57358575], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67562264], dtype=float32),
#   'logits': array([ 0.73372722], dtype=float32),
#   'probabilities': array([ 0.32437736,  0.67562264], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41687074], dtype=float32),
#   'logits': array([-0.33563274], dtype=float32),
#   'probabilities': array([ 0.58312929,  0.41687071], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25930792], dtype=float32),
#   'logits': array([-1.04956877], dtype=float32),
#   'probabilities': array([ 0.74069208,  0.25930792], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46640441], dtype=float32),
#   'logits': array([-0.13458514], dtype=float32),
#   'probabilities': array([ 0.53359556,  0.46640438], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17058504], dtype=float32),
#   'logits': array([-1.5814867], dtype=float32),
#   'probabilities': array([ 0.8294149 ,  0.17058502], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13604113], dtype=float32),
#   'logits': array([-1.84856784], dtype=float32),
#   'probabilities': array([ 0.8639589 ,  0.13604113], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16978005], dtype=float32),
#   'logits': array([-1.58718693], dtype=float32),
#   'probabilities': array([ 0.83021992,  0.16978005], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46455365], dtype=float32),
#   'logits': array([-0.14202356], dtype=float32),
#   'probabilities': array([ 0.53544635,  0.46455368], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.05644027], dtype=float32),
#   'logits': array([-2.81647682], dtype=float32),
#   'probabilities': array([ 0.94355971,  0.05644026], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26781201], dtype=float32),
#   'logits': array([-1.00575197], dtype=float32),
#   'probabilities': array([ 0.73218799,  0.26781204], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15973206], dtype=float32),
#   'logits': array([-1.66022301], dtype=float32),
#   'probabilities': array([ 0.8402679 ,  0.15973206], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24190125], dtype=float32),
#   'logits': array([-1.14228404], dtype=float32),
#   'probabilities': array([ 0.75809872,  0.24190125], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23056725], dtype=float32),
#   'logits': array([-1.20511103], dtype=float32),
#   'probabilities': array([ 0.76943272,  0.23056722], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25856516], dtype=float32),
#   'logits': array([-1.0534395], dtype=float32),
#   'probabilities': array([ 0.74143487,  0.25856519], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74990445], dtype=float32),
#   'logits': array([ 1.09810281], dtype=float32),
#   'probabilities': array([ 0.25009552,  0.74990445], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16202091], dtype=float32),
#   'logits': array([-1.64326775], dtype=float32),
#   'probabilities': array([ 0.83797908,  0.16202091], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11490942], dtype=float32),
#   'logits': array([-2.04154587], dtype=float32),
#   'probabilities': array([ 0.88509059,  0.11490942], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56366682], dtype=float32),
#   'logits': array([ 0.25605726], dtype=float32),
#   'probabilities': array([ 0.43633315,  0.56366682], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4354198], dtype=float32),
#   'logits': array([-0.2597717], dtype=float32),
#   'probabilities': array([ 0.5645802 ,  0.43541983], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.83262146], dtype=float32),
#   'logits': array([ 1.604321], dtype=float32),
#   'probabilities': array([ 0.16737856,  0.83262146], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60569823], dtype=float32),
#   'logits': array([ 0.42926526], dtype=float32),
#   'probabilities': array([ 0.3943018 ,  0.60569823], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1154348], dtype=float32),
#   'logits': array([-2.0363903], dtype=float32),
#   'probabilities': array([ 0.88456523,  0.1154348 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62839025], dtype=float32),
#   'logits': array([ 0.52531707], dtype=float32),
#   'probabilities': array([ 0.37160978,  0.62839025], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51952291], dtype=float32),
#   'logits': array([ 0.07813132], dtype=float32),
#   'probabilities': array([ 0.48047709,  0.51952291], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76379526], dtype=float32),
#   'logits': array([ 1.17360067], dtype=float32),
#   'probabilities': array([ 0.23620477,  0.76379526], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21037145], dtype=float32),
#   'logits': array([-1.32268786], dtype=float32),
#   'probabilities': array([ 0.78962857,  0.21037146], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15865138], dtype=float32),
#   'logits': array([-1.66829693], dtype=float32),
#   'probabilities': array([ 0.84134865,  0.15865138], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50480914], dtype=float32),
#   'logits': array([ 0.01923704], dtype=float32),
#   'probabilities': array([ 0.49519089,  0.50480914], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14362735], dtype=float32),
#   'logits': array([-1.7854836], dtype=float32),
#   'probabilities': array([ 0.85637265,  0.14362735], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75018859], dtype=float32),
#   'logits': array([ 1.09961843], dtype=float32),
#   'probabilities': array([ 0.2498114 ,  0.75018859], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50844646], dtype=float32),
#   'logits': array([ 0.03378892], dtype=float32),
#   'probabilities': array([ 0.4915536 ,  0.50844646], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15969898], dtype=float32),
#   'logits': array([-1.66046953], dtype=float32),
#   'probabilities': array([ 0.84030098,  0.15969896], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52395165], dtype=float32),
#   'logits': array([ 0.09588003], dtype=float32),
#   'probabilities': array([ 0.47604835,  0.52395165], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42416492], dtype=float32),
#   'logits': array([-0.30569893], dtype=float32),
#   'probabilities': array([ 0.57583505,  0.42416492], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10622182], dtype=float32),
#   'logits': array([-2.12992811], dtype=float32),
#   'probabilities': array([ 0.8937782 ,  0.10622182], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48222086], dtype=float32),
#   'logits': array([-0.07114661], dtype=float32),
#   'probabilities': array([ 0.51777917,  0.48222086], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55861795], dtype=float32),
#   'logits': array([ 0.23555493], dtype=float32),
#   'probabilities': array([ 0.44138208,  0.55861795], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7248823], dtype=float32),
#   'logits': array([ 0.96881056], dtype=float32),
#   'probabilities': array([ 0.27511761,  0.7248823 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77751613], dtype=float32),
#   'logits': array([ 1.25124955], dtype=float32),
#   'probabilities': array([ 0.22248393,  0.77751613], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40204185], dtype=float32),
#   'logits': array([-0.39696455], dtype=float32),
#   'probabilities': array([ 0.59795815,  0.40204185], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15142569], dtype=float32),
#   'logits': array([-1.72346258], dtype=float32),
#   'probabilities': array([ 0.84857428,  0.15142569], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.07885885], dtype=float32),
#   'logits': array([-2.45795369], dtype=float32),
#   'probabilities': array([ 0.92114121,  0.07885886], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.09871], dtype=float32),
#   'logits': array([-2.21164083], dtype=float32),
#   'probabilities': array([ 0.90129   ,  0.09870999], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25252753], dtype=float32),
#   'logits': array([-1.08517718], dtype=float32),
#   'probabilities': array([ 0.74747241,  0.25252751], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30465278], dtype=float32),
#   'logits': array([-0.82523865], dtype=float32),
#   'probabilities': array([ 0.69534725,  0.30465281], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26343271], dtype=float32),
#   'logits': array([-1.02820265], dtype=float32),
#   'probabilities': array([ 0.73656732,  0.26343271], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmppyqcfkqm
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmppyqcfkqm', '_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_tf_random_seed': 1, '_save_summary_steps': 100, '_session_config': None, '_keep_checkpoint_max': 5}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py

dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-0acf193fb5de> in <module>()
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~/.conda/envs/tfl/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps)
#     239       hooks.append(training.StopAtStepHook(steps, max_steps))
#     240
# --> 241     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     242     logging.info('Loss for final step: %s.', loss)
#     243     return self
#
# ~/.conda/envs/tfl/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks)
#     628           input_fn, model_fn_lib.ModeKeys.TRAIN)
#     629       estimator_spec = self._call_model_fn(features, labels,
# --> 630                                            model_fn_lib.ModeKeys.TRAIN)
#     631       ops.add_to_collection(ops.GraphKeys.LOSSES, estimator_spec.loss)
#     632       all_hooks.extend(hooks)
#
# ~/.conda/envs/tfl/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode)
#     613     if 'config' in model_fn_args:
#     614       kwargs['config'] = self.config
# --> 615     model_fn_results = self._model_fn(features=features, **kwargs)
#     616
#     617     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# ~/.conda/envs/tfl/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     269           dropout=dropout,
#     270           input_layer_partitioner=input_layer_partitioner,
# --> 271           config=config)
#     272     super(DNNClassifier, self).__init__(
#     273         model_fn=_model_fn, model_dir=model_dir, config=config)
#
# ~/.conda/envs/tfl/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     100       net = feature_column_lib.input_layer(
#     101           features=features,
# --> 102           feature_columns=feature_columns)
#     103
#     104     for layer_id, num_hidden_units in enumerate(hidden_units):
#
# ~/.conda/envs/tfl/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/feature_column/feature_column.py in input_layer(features, feature_columns, weight_collections, trainable)
#     211           'Items of feature_columns must be a _DenseColumn. '
#     212           'You can wrap a categorical column with an '
# --> 213           'embedding_column or indicator_column. Given: {}'.format(column))
#     214   weight_collections = list(weight_collections or [])
#     215   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
# creates dense_pack column
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmpu3tm8nw4
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmpu3tm8nw4', '_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_tf_random_seed': 1, '_save_summary_steps': 100, '_session_config': None, '_keep_checkpoint_max': 5}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmpu3tm8nw4/model.ckpt.
# INFO:tensorflow:loss = 8.88991, step = 1
# INFO:tensorflow:global_step/sec: 470.071
# INFO:tensorflow:loss = 7.26126, step = 101 (0.214 sec)
# INFO:tensorflow:global_step/sec: 559.936
# INFO:tensorflow:loss = 6.69526, step = 201 (0.180 sec)
# INFO:tensorflow:global_step/sec: 534.682
# INFO:tensorflow:loss = 5.13364, step = 301 (0.186 sec)
# INFO:tensorflow:global_step/sec: 563.964
# INFO:tensorflow:loss = 3.30179, step = 401 (0.180 sec)
# INFO:tensorflow:global_step/sec: 562.841
# INFO:tensorflow:loss = 6.56008, step = 501 (0.177 sec)
# INFO:tensorflow:global_step/sec: 482.712
# INFO:tensorflow:loss = 5.07409, step = 601 (0.207 sec)
# INFO:tensorflow:global_step/sec: 497.74
# INFO:tensorflow:loss = 4.64558, step = 701 (0.200 sec)
# INFO:tensorflow:global_step/sec: 611.362
# INFO:tensorflow:loss = 4.62908, step = 801 (0.165 sec)
# INFO:tensorflow:global_step/sec: 602.392
# INFO:tensorflow:loss = 4.6487, step = 901 (0.166 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmpu3tm8nw4/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.67774.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2020-02-14-22:50:48
# INFO:tensorflow:Restoring parameters from /var/folders/9y/n0rxh9rj60q4v8zgsclp0gm97tm33p/T/tmpu3tm8nw4/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2020-02-14-22:50:49
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.748031, accuracy_baseline = 0.65748, auc = 0.812857, auc_precision_recall = 0.654515, average_loss = 0.508322, global_step = 1000, label/mean = 0.34252, loss = 4.96591, prediction/mean = 0.35679
# {'accuracy': 0.7480315,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.81285697,
#  'auc_precision_recall': 0.65451527,
#  'average_loss': 0.50832152,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 4.96591,
#  'prediction/mean': 0.35679042}

# %% [markdown]
# # Great Job!
